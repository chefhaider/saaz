# %%
from mido import MidiFile
mid = MidiFile('output.mid')  
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
# Out:
# Track 0:
# MetaMessage('set_tempo', tempo=500000, time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('end_of_track', time=1024)
# Track 1: Sitar
# MetaMessage('track_name', name='Sitar', time=0)
# program_change channel=0 program=104 time=0
# pitchwheel channel=0 pitch=0 time=0
# program_change channel=0 program=104 time=0
# note_on channel=0 note=60 velocity=55 time=0
# note_on channel=0 note=88 velocity=28 time=0
# note_on channel=0 note=98 velocity=28 time=0
# note_on channel=0 note=101 velocity=18 time=0
# note_on channel=0 note=74 velocity=31 time=0
# note_on channel=0 note=77 velocity=27 time=0
# note_on channel=0 note=82 velocity=26 time=0
# note_on channel=0 note=85 velocity=11 time=0
# note_on channel=0 note=90 velocity=9 time=0
# note_on channel=0 note=93 velocity=15 time=0
# note_on channel=0 note=60 velocity=49 time=0
# note_on channel=0 note=68 velocity=56 time=0
# ...

# %%
import pretty_midi

midi_data = pretty_midi.PrettyMIDI('sample1.midi')
print("duration:",midi_data.get_end_time())
print(f'{"note":>10} {"start":>10} {"end":>10}')
for instrument in midi_data.instruments:
    print("instrument:", instrument.program)
    for note in instrument.notes:
        print(f'{note.pitch:10} {note.start:10} {note.end:10}')

# %% [markdown]
# Converting midi instrument from piano to sitar

# %%
from music21 import converter,instrument # or import *
s = converter.parse('sample1.midi')

for el in s.recurse():
    if 'Instrument' in el.classes: # or 'Piano'
        el.activeSite.replace(el, instrument.Sitar())

s.write('midi', 'output.mid')
# Out:
# 'output.mid'
